# %% [markdown]
# <a href="https://colab.research.google.com/github/dsivov/MyColabs/blob/main/sumy_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install sumy
! pip install --index-url http://74.82.29.209:8090 nebula3_database==0.2.2 --trusted-host 74.82.29.209
! pip install spacy
! pip install openai
! pip install fastcoref

import nltk
nltk.download('punkt')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sumy
#   Downloading sumy-0.11.0-py2.py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.3/97.3 KB 3.1 MB/s eta 0:00:00
# Collecting docopt<0.7,>=0.6.1
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting breadability>=0.1.20
#   Downloading breadability-0.1.20.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python3.8/dist-packages (from sumy) (2.25.1)
# Requirement already satisfied: nltk>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from sumy) (3.7)
# Collecting pycountry>=18.2.23
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 26.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: chardet in /usr/local/lib/python3.8/dist-packages (from breadability>=0.1.20->sumy) (4.0.0)
# Requirement already satisfied: lxml>=2.0 in /usr/local/lib/python3.8/dist-packages (from breadability>=0.1.20->sumy) (4.9.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk>=3.0.2->sumy) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk>=3.0.2->sumy) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk>=3.0.2->sumy) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk>=3.0.2->sumy) (4.64.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from pycountry>=18.2.23->sumy) (57.4.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.7.0->sumy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.7.0->sumy) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.7.0->sumy) (1.24.3)
# Building wheels for collected packages: breadability, docopt, pycountry
#   Building wheel for breadability (setup.py) ... done
#   Created wheel for breadability: filename=breadability-0.1.20-py2.py3-none-any.whl size=21714 sha256=a75dc8dd7e435b6f32177bc703b27dbdd134d3397f894638e05765ae6bac7fc8
#   Stored in directory: /root/.cache/pip/wheels/5f/0d/0c/2062d8c1758b4b1a2e42b4a63e6660d9ec2ba9463cfee9eeab
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=b4ac897ec8682507c23e29556ed123042f14c7f326141c749563d69d75e3419d
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
#   Building wheel for pycountry (pyproject.toml) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681845 sha256=53311cd965ab5276ffbd1e9396d752463f4fd9edf4d7e24770502d3f15eae768
#   Stored in directory: /root/.cache/pip/wheels/e2/aa/0f/c224e473b464387170b83ca7c66947b4a7e33e8d903a679748
# Successfully built breadability docopt pycountry
# Installing collected packages: docopt, pycountry, breadability, sumy
# Successfully installed breadability-0.1.20 docopt-0.6.2 pycountry-22.3.5 sumy-0.11.0
# Looking in indexes: http://74.82.29.209:8090, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nebula3_database==0.2.2
#   Downloading http://74.82.29.209:8090/packages/nebula3_database-0.2.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from nebula3_database==0.2.2) (1.21.6)
# Collecting python-arango==7.2.0
#   Downloading python_arango-7.2.0-py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 KB 4.1 MB/s eta 0:00:00
# Collecting pymilvus==1.1.1
#   Downloading pymilvus-1.1.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 KB 7.5 MB/s eta 0:00:00
# Collecting ujson>=2.0.0
#   Downloading ujson-5.7.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 KB 7.1 MB/s eta 0:00:00
# Collecting grpcio-tools<1.38.0,>=1.22.0
#   Downloading grpcio_tools-1.37.1-cp38-cp38-manylinux2014_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 40.5 MB/s eta 0:00:00
# Collecting grpcio<1.38.0,>=1.22.0
#   Downloading grpcio-1.37.1-cp38-cp38-manylinux2014_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 89.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.8/dist-packages (from pymilvus==1.1.1->nebula3_database==0.2.2) (2.25.1)
# Requirement already satisfied: setuptools>=42 in /usr/local/lib/python3.8/dist-packages (from python-arango==7.2.0->nebula3_database==0.2.2) (57.4.0)
# Collecting urllib3>=1.26.0
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 16.6 MB/s eta 0:00:00
# Collecting PyJWT
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Collecting setuptools-scm[toml]>=3.4
#   Downloading setuptools_scm-7.1.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 KB 5.3 MB/s eta 0:00:00
# Collecting requests-toolbelt
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.8/dist-packages (from grpcio<1.38.0,>=1.22.0->pymilvus==1.1.1->nebula3_database==0.2.2) (1.15.0)
# Requirement already satisfied: protobuf<4.0dev,>=3.5.0.post1 in /usr/local/lib/python3.8/dist-packages (from grpcio-tools<1.38.0,>=1.22.0->pymilvus==1.1.1->nebula3_database==0.2.2) (3.19.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22.0->pymilvus==1.1.1->nebula3_database==0.2.2) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22.0->pymilvus==1.1.1->nebula3_database==0.2.2) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22.0->pymilvus==1.1.1->nebula3_database==0.2.2) (4.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from setuptools-scm[toml]>=3.4->python-arango==7.2.0->nebula3_database==0.2.2) (4.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from setuptools-scm[toml]>=3.4->python-arango==7.2.0->nebula3_database==0.2.2) (21.3)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from setuptools-scm[toml]>=3.4->python-arango==7.2.0->nebula3_database==0.2.2) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->setuptools-scm[toml]>=3.4->python-arango==7.2.0->nebula3_database==0.2.2) (3.0.9)
# Installing collected packages: urllib3, ujson, PyJWT, grpcio, setuptools-scm, grpcio-tools, requests-toolbelt, pymilvus, python-arango, nebula3_database
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.51.1
#     Uninstalling grpcio-1.51.1:
#       Successfully uninstalled grpcio-1.51.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.48.2 requires grpcio>=1.48.2, but you have grpcio 1.37.1 which is incompatible.
# google-cloud-bigquery 3.4.1 requires grpcio<2.0dev,>=1.47.0, but you have grpcio 1.37.1 which is incompatible.
# Successfully installed PyJWT-2.6.0 grpcio-1.37.1 grpcio-tools-1.37.1 nebula3_database-0.2.2 pymilvus-1.1.1 python-arango-7.2.0 requests-toolbelt-0.10.1 setuptools-scm-7.1.0 ujson-5.7.0 urllib3-1.26.14
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.4)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (21.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.11)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.6)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.25.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.0.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.26.1.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 KB 3.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.8/dist-packages (from openai) (2.25.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from openai) (4.64.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from openai) (3.8.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (4.0.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (2.1.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (22.2.0)
# Building wheels for collected packages: openai
#   Building wheel for openai (pyproject.toml) ... done
#   Created wheel for openai: filename=openai-0.26.1-py3-none-any.whl size=67316 sha256=c7e6f7bd4164a993b6a8831f4894aa37f87c15fa021ec49dc26fa9b1167e704f
#   Stored in directory: /root/.cache/pip/wheels/2f/9c/55/95d3609ccfc463eeffb96d50c756f1f1899453b85e92021a0a
# Successfully built openai
# Installing collected packages: openai
# Successfully installed openai-0.26.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fastcoref
#   Downloading fastcoref-2.1.1.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.8/dist-packages (from fastcoref) (4.64.1)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.8/dist-packages (from fastcoref) (1.21.6)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.8/dist-packages (from fastcoref) (1.7.3)
# Requirement already satisfied: spacy>=3.0.6 in /usr/local/lib/python3.8/dist-packages (from fastcoref) (3.4.4)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.8/dist-packages (from fastcoref) (1.13.0+cu116)
# Collecting transformers>=4.11.3
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 47.2 MB/s eta 0:00:00
# Collecting datasets>=2.5.2
#   Downloading datasets-2.8.0-py3-none-any.whl (452 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.9/452.9 KB 32.7 MB/s eta 0:00:00
# Collecting wandb>=0.13.4
#   Downloading wandb-0.13.9-py2.py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 60.2 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from datasets>=2.5.2->fastcoref) (2.25.1)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 15.6 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.2.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from datasets>=2.5.2->fastcoref) (6.0)
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.8/dist-packages (from datasets>=2.5.2->fastcoref) (0.3.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets>=2.5.2->fastcoref) (3.8.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from datasets>=2.5.2->fastcoref) (21.3)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets>=2.5.2->fastcoref) (2022.11.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets>=2.5.2->fastcoref) (1.3.5)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets>=2.5.2->fastcoref) (9.0.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->fastcoref) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->fastcoref) (1.0.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->fastcoref) (2.0.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->fastcoref) (2.11.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->fastcoref) (6.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->fastcoref) (1.10.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->fastcoref) (2.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->fastcoref) (0.10.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->fastcoref) (3.0.11)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->fastcoref) (2.4.5)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->fastcoref) (8.1.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->fastcoref) (3.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->fastcoref) (3.3.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->fastcoref) (0.10.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->fastcoref) (0.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->fastcoref) (57.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.10.0->fastcoref) (4.4.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 72.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers>=4.11.3->fastcoref) (3.9.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers>=4.11.3->fastcoref) (2022.6.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb>=0.13.4->fastcoref) (5.4.8)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.30-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.8/dist-packages (from wandb>=0.13.4->fastcoref) (1.4.4)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.13.0-py2.py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 KB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from wandb>=0.13.4->fastcoref) (3.19.6)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.8/dist-packages (from wandb>=0.13.4->fastcoref) (7.1.2)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from docker-pycreds>=0.4.0->wandb>=0.13.4->fastcoref) (1.15.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.5.2->fastcoref) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.5.2->fastcoref) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.5.2->fastcoref) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.5.2->fastcoref) (6.0.4)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.5.2->fastcoref) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.5.2->fastcoref) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.5.2->fastcoref) (22.2.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->datasets>=2.5.2->fastcoref) (3.0.9)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets>=2.5.2->fastcoref) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets>=2.5.2->fastcoref) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets>=2.5.2->fastcoref) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets>=2.5.2->fastcoref) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.0.6->fastcoref) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.0.6->fastcoref) (0.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy>=3.0.6->fastcoref) (2.0.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets>=2.5.2->fastcoref) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets>=2.5.2->fastcoref) (2.8.2)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: fastcoref, pathtools
#   Building wheel for fastcoref (setup.py) ... done
#   Created wheel for fastcoref: filename=fastcoref-2.1.1-py3-none-any.whl size=30823 sha256=388a3e8bee99001d7022d8f2d1043282c811d471ebf22f4f7fbf02d3f6982e03
#   Stored in directory: /root/.cache/pip/wheels/80/3d/3c/ff2b888aca019cef6ae096f5f8983e4891d6be3eb7cfffeda3
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=297b697b80d90291f8ebd2ce05974bd0bd23a289df499a0a5259289d55108656
#   Stored in directory: /root/.cache/pip/wheels/4c/8e/7e/72fbc243e1aeecae64a96875432e70d4e92f3d2d18123be004
# Successfully built fastcoref pathtools
# Installing collected packages: tokenizers, pathtools, xxhash, smmap, setproctitle, sentry-sdk, multiprocess, docker-pycreds, responses, huggingface-hub, gitdb, transformers, GitPython, wandb, datasets, fastcoref
# Successfully installed GitPython-3.1.30 datasets-2.8.0 docker-pycreds-0.4.0 fastcoref-2.1.1 gitdb-4.0.10 huggingface-hub-0.11.1 multiprocess-0.70.14 pathtools-0.1.2 responses-0.18.0 sentry-sdk-1.13.0 setproctitle-1.3.2 smmap-5.0.0 tokenizers-0.13.2 transformers-4.25.1 wandb-0.13.9 xxhash-3.2.0
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
text = """0. A man is standing on a baseball diamond throwing a ball. The man is wearing a Baseball uniform, cap, and glove. The man is surrounded by a lush green grass field. Behind him there is an outfield wall, with a line of tree's beyond it.
    1. There is a young boy playing ball on a field. The boy has on a baseball cap and holds a baseball glove in his right hand. The grassy field has a single mitt and a baseball bat. In the middle of the field, there is a baseball diamond with dirt infields and grass outfield. A few trees are located in the background.
    2. The person is riding a black motorcycle on a road surrounded by trees. The person is wearing a black helmet and black biker gear. The trees are green with a few of them being partly yellow, probably due to the change of seasons. There is a blue sky in the background. The rider is going faster than usual, as indicated by the blurred background highlighted by the sun.
    3. This image depicts a baseball game taking place. There is a batter standing at the plate with a bat in hand, about to hit a ball. There is a catcher standing behind the batter. Behind the catcher, there are outfielders and infielders in the background. There is an umpire behind the catcher and the pitcher is throwing the ball from the bullpen. The bat and ball are in the foreground of the image.
    4. A person riding a bike is seen speeding downhill with the wind blowing their hair behind them. They are going down a winding path that has lush green trees to either side. The person has on a red jacket and jeans.
    5. A person is playing a game of frisbee on a grassy lawn. The background is a baseball diamond with stands and trees on either side.
    6. A group of young people are playing a game of baseball. All the players are dressed in baseball gear including caps, bats and gloves. All of them are standing on the baseball field. In the background there's a crowd of people watching the game."""

# %%
text = """0. This movie shows two men talking in a small room. The men have serious expressions on their faces.
    1. A man sits in a large metal cage with bars. Behind him a woman stands just inside the cage. Her hands are placed on the bars of the cage. A small window with metal bars is in the background, letting in a small amount of light.
    2. Two men are in a jail cell, one is speaking and gesturing while the other looks on. His eyes are wide and his mouth is open as if he is speaking through an animated gesture. There is a barred window in the background and the jail cell is sparsely decorated.
    3. Two men are standing together in a hallway. One man is wearing a navy blue suit and the other is wearing a police uniform. They are both smiling and looking at each other. The man in the police uniform has his hands on his hips.
    4. The movie shows two men facing one another in a narrow, dimly lit room. There are iron bars along one side of the room. The men both have handcuffs on their wrists. Both men look serious and tense as if they're having a stand off.
    5. The movie is of two men in a room having a conversation. He has glasses on and a small goatee. He is making eye contact with the other man and has a smirk on his face. He is bald and has a grin on his face.
    6. In this movie, a group of people are standing in a jail cell area. There are jail bars separating them from the area outside. A police officer is standing in the background, and two prisoners are standing in the foreground.
    7. One of them is holding a pair of handcuffs in his hand and the other man is wearing a pair of handcuffs. Both of the men are in a jail cell, which is bare except for the wall and a small bench. In the background, there are other jail cells and a barred window looking out into an elevator lobby or elevator shaft.
    8. A man and a woman are in a jail cell room. The man is wearing a black shirt and the woman is wearing a red shirt. Both of them have grimaces on their faces as if they are in a tense situation. Behind them is a barred window.
    9. The movie is of a group of people crowded inside a jail cell. The cell is constructed out of cold gray metal bars. The people are looking tired and anxious; some even seem to be asleep, while others are standing and talking. In the background, light from a few windows barely illuminate the dreary cell."""

# %%
text = """0. A little girl is standing in a television studio wearing a beautiful pink dress. She has a microphone in her hand and is smiling brightly as if she is about to perform. Her expression is one of pure joy and excitement.
    1. A woman dressed in a black dress is sitting on a red chair. She has her hands placed on her lap, and is looking straight ahead. Her dress has a low cut neckline which reveals her cleavage. She is wearing dark shades on her eyes. The chair is against a plain white wall with a single light next to it. There is a microphone in front of her.
    2. In the movie, there is a group of people sitting in a row on a stage. The people seem to be part of a vocal choir. Each of the people have a mic in front of them and they are looking towards the audience. Behind them there are other people that are standing. There are speakers behind the standing people and a large curtain behind them.
    3. A young girl is standing on a red stage singing into a microphone. She is wearing a pink dress and has her hair tied up in a bun. There is a spotlight in the middle of the stage lighting up the girl. There is a large audience watching her perform.
    4. There are two men sitting on a red and black chair with wheels in what looks like a music studio. The man on the left is wearing a black hoodie and blue jeans and has a white baseball cap on backwards. He has brown hair and a full beard. The man on the right is wearing a white t-shirt and blue jeans and has a shaved head. He has a full beard. Both men have black headphones on their heads and cups of coffee on a table next to them.
    5. A young girl is holding a microphone and singing into it on a red performance stage. Her hair is brown and her eyes are closed, and she appears to be very passionate and enthralled in the moment. The stage is a deep, red color with a single white spot light shining down on her."""

# %%
from __future__ import absolute_import
from __future__ import division, print_function, unicode_literals

from sumy.parsers.html import HtmlParser
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer as Summarizer
from sumy.nlp.stemmers import Stemmer
from sumy.utils import get_stop_words


LANGUAGE = "english"
SENTENCES_COUNT = 10


#prompt = "Summarise following text:\n"
prompt = "Extract 5 important actions from following text:\n"
prompt = ""
#prompt = "Generate long title from captions:\n"
#prompt = "Generate few captivating headings from captions:\n"
#prompt = "Create few summarising headings from captions:\n"
#prompt = "what happens in the scene described by the following text?:\n"
parser = PlaintextParser.from_string(text, Tokenizer(LANGUAGE))    
stemmer = Stemmer(LANGUAGE)

summarizer = Summarizer(stemmer)
summarizer.stop_words = get_stop_words(LANGUAGE)

for sentence in summarizer(parser.document, SENTENCES_COUNT):
    prompt = prompt + str(sentence)
print(prompt)
# Out:
# A little girl is standing in a television studio wearing a beautiful pink dress.Her dress has a low cut neckline which reveals her cleavage.A young girl is standing on a red stage singing into a microphone.There are two men sitting on a red and black chair with wheels in what looks like a music studio.The man on the left is wearing a black hoodie and blue jeans and has a white baseball cap on backwards.The man on the right is wearing a white t-shirt and blue jeans and has a shaved head.Both men have black headphones on their heads and cups of coffee on a table next to them.A young girl is holding a microphone and singing into it on a red performance stage.Her hair is brown and her eyes are closed, and she appears to be very passionate and enthralled in the moment.The stage is a deep, red color with a single white spot light shining down on her.

# %%
from fastcoref import spacy_component
import spacy


#text = 'Alice goes down the rabbit hole. Where she would discover a new reality beyond her expectations.'

nlp = spacy.load("en_core_web_sm")
nlp.add_pipe("fastcoref")

doc = nlp(prompt, component_cfg={"fastcoref": {'resolve_text': True}})
print(doc._.coref_clusters)
print(doc._.resolved_text)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
# Inference:   0%|          | 0/1 [00:00<?, ?it/s]
# [[(0, 13), (80, 83), (127, 130), (140, 152), (580, 592), (664, 667), (686, 689), (711, 714), (852, 855)], [(57, 79), (80, 89)], [(216, 302), (491, 499), (525, 530), (575, 579)], [(193, 205), (604, 616), (634, 636)], [(168, 179), (640, 663), (774, 783)]]
# A little girl is standing in a television studio wearing a beautiful pink dress.A little girl's dress has a low cut neckline which reveals A little girl's cleavage.A little girl is standing on a red stage singing into a microphone.There are two men sitting on a red and black chair with wheels in what looks like a music studio.The man on the left is wearing a black hoodie and blue jeans and has a white baseball cap on backwards.The man on the right is wearing a white t-shirt and blue jeans and has a shaved head.two men sitting on a red and black chair with wheels in what looks like a music studio have black headphones on two men sitting on a red and black chair with wheels in what looks like a music studio's heads and cups of coffee on a table next to two men sitting on a red and black chair with wheels in what looks like a music studio.A little girl is holding a microphone and singing into a microphone on a red stage.A little girl's hair is brown and A little girl's eyes are closed, and A little girl appears to be very passionate and enthralled in the moment.a red stage is a deep, red color with a single white spot light shining down on A little girl.

# %%
import openai

# %%
#prompt = "Generate captivating heading from captions of movie:\n" + text
response = openai.Completion.create(
  engine="text-davinci-003",
  prompt=prompt,
  temperature=0.0,
  max_tokens=256
  #top_p=1.0,
  #frequency_penalty=0.0,
  #presence_penalty=0.0
)


print(response['choices'][0]['text'])
# Out:
# 1. Girl is standing in a television studio wearing a pink dress.
# 2. Two men are sitting on a red and black chair with wheels in a music studio.
# 3. Both men have black headphones on their heads and cups of coffee on a table next to them.
# 4. Young girl is holding a microphone and singing into it on a red performance stage.
# 5. Stage is a deep, red color with a single white spot light shining down on her.
